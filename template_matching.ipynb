# %%
import cv2
from PIL import Image

img = cv2.imread("img_templates/angled-bottom-right.png")

Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=65x64>

# %%
img = cv2.imread("data/examples/Screenshot from 2026-02-13 11-08-33.png")

img_copy = img.copy()
cv2.rectangle(img_copy, (140,120), (360,180), (0,0,255), 2)

Image.fromarray(img_copy)
# Out:
# <PIL.Image.Image image mode=RGB size=552x360>

# %%
img_copy = img.copy()
cv2.rectangle(img_copy, (140,120), (450,300), (0,0,255), 2)

Image.fromarray(img_copy)
# Out:
# <PIL.Image.Image image mode=RGB size=552x360>

# %%
xe1, xe2, ye1, ye2 = 140, 450, 120, 300
img_crop = img[ye1:ye2, xe1:xe2]

Image.fromarray(img_crop)
# Out:
# <PIL.Image.Image image mode=RGB size=310x180>
